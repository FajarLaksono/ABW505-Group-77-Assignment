# %% [markdown]
# # Book Management

# %% [markdown]
# You can adjust everything according to ypur task
#
# call your function from here, and do main menu here

# %% [markdown]
# This is the example:

# %%
import sys
import os

notebook_dir = os.path.join(os.getcwd(), 'Project-1', 'Loan-Management')
sys.path.insert(0, notebook_dir)

import book

while True:
    print("Menu: \n1. Enter Name \n2. Exit")
    
    chosen_menu = input("Choose : ")
    
    if chosen_menu == '1':
        book.your_name()
    elif chosen_menu == '2':
        print("Exiting the program. Goodbye!")
        break
    else:
        print("Invalid choice. Please enter 1 or 2.")
# Out:
# Menu:
# 1. Enter Name
# 2. Exit
# Invalid choice. Please enter 1 or 2.
# Menu:
# 1. Enter Name
# 2. Exit
# Invalid choice. Please enter 1 or 2.
# Menu:
# 1. Enter Name
# 2. Exit
# 23123
# Menu:
# 1. Enter Name
# 2. Exit
# Exiting the program. Goodbye!
